# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
team_data = pd.read_csv('stats.csv')
team_data.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
# ...

# %%
team_data.describe()
# Out:
#              wins      losses       goals  total_yel_card  total_red_card  \
# count  240.000000  240.000000  240.000000      240.000000      240.000000
# mean    14.150000   14.150000   51.062500       61.079167        2.862500
# std      6.022482    5.596846   16.203474       10.078249        1.802442
# min      1.000000    2.000000   20.000000       38.000000        0.000000
# 25%     10.000000   10.000000   40.000000       54.000000        1.000000
# 50%     12.000000   15.000000   47.000000       60.500000        3.000000
# 75%     18.000000   19.000000   61.000000       67.000000        4.000000
# max     32.000000   29.000000  106.000000       94.000000        9.000000
#
#        total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  \
# count         240.000000            240.000000    240.000000   240.000000
# mean          514.241667            168.116667     12.283333     9.016667
# std            95.979164             38.748882      4.820950     3.659077
# ...

# %%
team_data[['wins', 'losses', 'goals', 'total_yel_card', 'total_red_card']].median()
# Out:
# wins              12.0
# losses            15.0
# goals             47.0
# total_yel_card    60.5
# total_red_card     3.0
# dtype: float64

# %%
top_6_teams = team_data[team_data['team'].isin(['Manchester United', 'Chelsea', 'Liverpool', 'Arsenal', 'Tottenham Hotspur', 'Manchester City'])][['team', 'wins', 'season']].reset_index(drop=True)
top_6_teams
# Out:
#                  team  wins     season
# 0   Manchester United  28.0  2006-2007
# 1             Chelsea  24.0  2006-2007
# 2           Liverpool  20.0  2006-2007
# 3             Arsenal  19.0  2006-2007
# 4   Tottenham Hotspur  17.0  2006-2007
# ..                ...   ...        ...
# 67  Manchester United  25.0  2017-2018
# 68  Tottenham Hotspur  23.0  2017-2018
# 69            Chelsea  21.0  2017-2018
# 70          Liverpool  21.0  2017-2018
# 71            Arsenal  19.0  2017-2018
#
# [72 rows x 3 columns]

# %%
plt.figure(figsize=(12, 8))

# Loop through each team and plot their data
for team in top_6_teams['team'].unique():
    top_6_team_specific = top_6_teams[top_6_teams['team'] == team]
    plt.plot(top_6_team_specific['season'], top_6_team_specific['wins'], marker='o', label=team)

# Add labels and title
plt.xlabel('Season')
plt.ylabel('Wins')
plt.title('Season Wins for Each Team')
plt.legend(title='Team')
plt.grid(True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
manchester_united = team_data[team_data.team == 'Manchester United'][['team', 'wins', 'losses','season', 'clean_sheet']].reset_index(drop = True)
manchester_united.head()
# Out:
#                 team  wins  losses     season  clean_sheet
# 0  Manchester United  28.0     5.0  2006-2007         16.0
# 1  Manchester United  27.0     5.0  2007-2008         21.0
# 2  Manchester United  28.0     4.0  2008-2009         24.0
# 3  Manchester United  27.0     7.0  2009-2010         19.0
# 4  Manchester United  23.0     4.0  2010-2011         15.0

# %%
# we know that in a premier league season there are 38 games 
n = 38.0
manchester_united['win_percentage'] = manchester_united['wins']/n
manchester_united['clean_sheet_percentage'] = manchester_united['clean_sheet']/n
manchester_united
# Out:
#                  team  wins  losses     season  clean_sheet  win_percentage  \
# 0   Manchester United  28.0     5.0  2006-2007         16.0        0.736842
# 1   Manchester United  27.0     5.0  2007-2008         21.0        0.710526
# 2   Manchester United  28.0     4.0  2008-2009         24.0        0.736842
# 3   Manchester United  27.0     7.0  2009-2010         19.0        0.710526
# 4   Manchester United  23.0     4.0  2010-2011         15.0        0.605263
# 5   Manchester United  28.0     5.0  2011-2012         20.0        0.736842
# 6   Manchester United  28.0     5.0  2012-2013         13.0        0.736842
# 7   Manchester United  19.0    12.0  2013-2014         13.0        0.500000
# 8   Manchester United  20.0     8.0  2014-2015         11.0        0.526316
# 9   Manchester United  19.0    10.0  2015-2016         18.0        0.500000
# 10  Manchester United  18.0     5.0  2016-2017         17.0        0.473684
# ...

# %%
# Plotting the win percentage and clean sheet percentage
plt.figure(figsize=(10,6))
plt.plot(manchester_united['season'], manchester_united['win_percentage'], label='Win Percentage', marker='o')
plt.plot(manchester_united['season'], manchester_united['clean_sheet_percentage'], label='Clean Sheet Percentage', marker='o')

# Adding labels and title
plt.xlabel('Season')
plt.ylabel('Percentage')
plt.title('Comparison of Win Percentage and Clean Sheet Percentage')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
